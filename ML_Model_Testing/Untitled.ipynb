# %%
import pandas as pd
import sklearn
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 import sklearn
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/__init__.py:82, in <module>
#      80 from . import _distributor_init  # noqa: F401
#      81 from . import __check_build  # noqa: F401
# ---> 82 from .base import clone
#      83 from .utils._show_versions import show_versions
#      85 __all__ = [
#      86     "calibration",
#      87     "cluster",
#    (...)
#     128     "show_versions",
#     129 ]
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/base.py:17, in <module>
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#      20     _safe_tags,
#      21 )
# ...

# %%
pandas.__version__
sklearn.__version__

# %%
df = pd.read_parquet ('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-01.parquet')

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:1053, in _repr_html_(self)
#    1051 @property
#    1052 def shape(self) -> tuple[int, int]:
# -> 1053     """
#    1054     Return a tuple representing the dimensionality of the DataFrame.
#    1055
#    1056     See Also
#    1057     --------
#    1058     ndarray.shape : Tuple of array dimensions.
#    1059
#    1060     Examples
#    1061     --------
#    1062     >>> df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
#    1063     >>> df.shape
#    1064     (2, 2)
# ...
